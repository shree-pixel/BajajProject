# %% [markdown]
# <a href="https://colab.research.google.com/github/shree-pixel/BajajProject/blob/main/Untitled1_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# sample_data

# %%
# !git clone https://github.com/abhirampai/acne-detection.git
# Out:
# Cloning into 'acne-detection'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 45 (delta 7), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (45/45), 18.50 MiB | 11.10 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
cd acne-detection/
# Out:
# /content/acne-detection

# %%
# !python train_model.py
# Out:
# 2023-10-13 13:32:26.196110: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [INFO] loading images...
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7B8D1A795870>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7B8D1A795870>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7B8D1A795870>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7B8D1A795870>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7B8D1A795870>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7B8D1A795870>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7B8D1A795870>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7B8D1A795870>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7B8D1A795870>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7B8D1A795870>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7B8D1A795870>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7B8D1A795870>
# ...

# %%
import os
os.listdir("/content/acne-detection")
# Out:
# ['facemodel',
#  'README.md',
#  'face_detector',
#  'dataset',
#  'detect_acne.py',
#  'images.jpg',
#  'facemodel.model',
#  'train_model.py',
#  '.git',
#  'image1.jpg']

# %%
# !ls
# Out:
# dataset		face_detector  facemodel.model	images.jpg  train_model.py
# detect_acne.py	facemodel      image1.jpg	README.md

# %%
# !pwd
# Out:
# /content/acne-detection

# %%
import os

image_path = "/content/acne-detection/2.jpg"

if os.path.exists(image_path):
    print("Image file exists.")
else:
    print("Image file not found.")
cv2.imwrite("test_image.jpg", image)
# Out:
# Image file exists.
# True

# %%
import os

image_path = '/content/acne-detection/acne1.jpg'

if os.path.exists(image_path):
    print("Image file exists and can be loaded.")
else:
    print("Image file not found. Double-check the file path.")
# Out:
# Image file exists and can be loaded.

# %%
from IPython.display import Image, display

# Specify the image path
image_path = '/content/acne-detection/acne1.jpg'

# Display the image
display(Image(filename=image_path))

# %%
import os
image_path = '/content/acne-detection/acne1.jpg'
print(os.path.exists(image_path))
# Out:
# True

# %%
from google.colab.patches import cv2_imshow

# Load the image
image = cv2.imread(image_path)

# Check if the image is loaded successfully
if image is not None:
    print("Image loaded successfully.")
    (h, w) = image.shape[:2]

    # Display the image in Colab
    cv2_imshow(image)

    # Continue with the image processing code
else:
    print("Error: Unable to load the image.")
# Out:
# Image loaded successfully.
# <PIL.Image.Image image mode=RGB size=194x259>

# %%
# %run detect_acne.py
# Out:
# [INFO] loading face detector model...
# [INFO] loading face acne detector model...
# [INFO] computing face detections...
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /content/acne-detection/detect_acne.py in <module>
#      63                 # ordering, resize it to 224x224, and preprocess it
#      64                 face = image[startY:endY, startX:endX]
# ---> 65                 face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
#      66                 face = cv2.resize(face, (224, 224))
#      67                 face = img_to_array(face)
#
# error: OpenCV(4.8.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
import shutil
shutil.rmtree("/content/acne-detection/dataset/withoutAcne")
